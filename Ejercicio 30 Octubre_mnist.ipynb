# %% [markdown]
# Tarea
#
# - Crear una red convolucional con el dataset MNIST
# - Guardar el modelo con .save
# - Hacer Predicciones con imagenes
# - Realizar metricas de evaluación

# %% [markdown]
# # Importar Librerias

# %%
from keras.models import load_model
loaded_model = load_model('cifar10_model.keras')
from tensorflow.keras.datasets import mnist
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-cef2a8a014f7> in <cell line: 2>()
#       1 from keras.models import load_model
# ----> 2 loaded_model = load_model('cifar10_model.keras')
#       3 from tensorflow.keras.datasets import mnist
#       4 import warnings
#       5 warnings.filterwarnings('ignore')
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     191         )
#     192     elif str(filepath).endswith(".keras"):
# --> 193         raise ValueError(
#     194             f"File not found: filepath={filepath}. "
#     195             "Please ensure the file is an accessible `.keras` "
#
# ValueError: File not found: filepath=cifar10_model.keras. Please ensure the file is an accessible `.keras` zip file.

# %% [markdown]
# # Leer el Dataset

# %%
# Load the MNIST dataset
(ds_train, ds_test), ds_info = tfds.load(
    'mnist',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Print the shapes of the data to verify
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
#   File "<ipython-input-3-afe1765eb298>", line 2
#     (ds_train, ds_test), ds_info = tfds.load(
#                                             ^
# SyntaxError: '(' was never closed

# %% [markdown]
# # Definir el Modelo

# %%
# Define the CNN model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # Entrenar el Modelo

# %%
# Preprocess the data
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# Train the model
model.fit(x_train, y_train, epochs=5)

# %% [markdown]
# # Evaluar el modelo

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)

# %% [markdown]
# # Guardar el Modelo

# %%
model.save("mnist_model.keras")
print("Model saved as mnist_model.h5")

# %%
predict = model.predict(x_test)

# %%
y_pred = predict.argmax(axis=1)
y_pred

# %% [markdown]
# # Generar Matriz de Confusion

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm) # Assuming labels are 0, 1, 2
disp.plot()
plt.show()

# %% [markdown]
# # Generar Métricas

# %%
from sklearn.metrics import classification_report
report = classification_report(y_test, y_pred)
print(report)
