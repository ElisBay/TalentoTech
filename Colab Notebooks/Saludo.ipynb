# %%
x= int(input("Ingrese la hora actual: "))
if x>=0 or x<12:
    print("Buenos dias")
elif x>=12 or x<19:
    print("Buenas tardes")
elif x>=19 or x<24:
    print("Buenas noches")
# Out:
#   File "<ipython-input-23-cda81d913e43>", line 6
#     else x>=19 or x<24
#          ^
# SyntaxError: expected ':'
