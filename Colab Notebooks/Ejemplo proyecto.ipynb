# %% [markdown]
# # Cargar las Librerías y Componentes

# %%
# !pip install kaggle

# %%
# !kaggle datasets download -d mos3santos/breast-cancer-diagnosis
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mos3santos/breast-cancer-diagnosis
# License(s): unknown
# breast-cancer-diagnosis.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip breast-cancer-diagnosis.zip
# Out:
# Archive:  breast-cancer-diagnosis.zip
# replace Dados/Imagens/PACIENTE_0001/PAC_0001_IMG_0000.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# Ruta al directorio del dataset (actualiza esta ruta a la ubicación donde extrajiste el dataset)
data_dir = 'breast-cancer-diagnosis/data'  # Change to the extracted dataset directory

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import cv2
import os  # Asegúrate de importar la librería os

# Configuración para reproducibilidad
np.random.seed(42)
tf.random.set_seed(42)

# Ruta al directorio del dataset (actualiza esta ruta a la ubicación donde extrajiste el dataset)
# The previous path was incorrect. Update to the correct path where the 'benign' and 'malignant' folders are located.
# For example, if the dataset was extracted directly to the current directory, the path should be:
data_dir = 'IDC_regular_ps50_idx5/IDC_regular_ps50_idx5'

# Función para cargar imágenes y etiquetas
def load_data(data_dir):
    images = []
    labels = []
    for label in ['0', '1']: # Update to match the actual folder names
        path = os.path.join(data_dir, label)
        for img in os.listdir(path):
            img_path = os.path.join(path, img)

            # Check if the file is

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# ...
