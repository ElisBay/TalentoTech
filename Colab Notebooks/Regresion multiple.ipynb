# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
1. Partir datos
2. Entrenar el modelo
3. Predict
4. Evaluar
columna categórica: se deben codificar
limpieza
EDA (primero hay que hacer analisis exploratorio )

# %%
print([BMI]value_counts()
# Out:
#   File "<ipython-input-28-66e59b304d1a>", line 1
#     print([BMI]value_counts()
#          ^
# SyntaxError: '(' was never closed
