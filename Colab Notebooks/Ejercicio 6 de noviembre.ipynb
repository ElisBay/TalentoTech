# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importación del conjunto de datos

# %%
df = pd.read_csv('IMDB Dataset.csv')

print(df.head()) # To see the first 5 rows of the dataset
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("lakshmi25npathi/imdb-dataset-of-50k-movie-reviews")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews/versions/1

# %% [markdown]
# Descripción del conjunto de datos:

# %%
#checking Dataset Description
print (df.describe())
# Out:
#                                                    review sentiment
# count                                               50000     50000
# unique                                              49582         2
# top     Loved today's show!!! It was a variety and not...  positive
# freq                                                    5     25000

# %% [markdown]
# Recuento de Sentimientos

# %%
#sentiment Count
print ("total: \n", df['sentiment'].value_counts())
# Out:
# total:
#  sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %% [markdown]
# Inicialización de listas:

# %%
# Assuming 'df' contains your data and the review column is named 'review'
Review=[]
sentences= list(df['review']) # Replace 'IMDB' with 'df'
for sen in sentences:
    Review.append (sen)

# %% [markdown]
# Creación de etiquetas

# %%
labels = list(df['sentiment'])
labels=np.array(list (map(lambda x: 1 if x=="positive" else 0, labels)))

# %% [markdown]
# División de datos de entrenamiento y prueba:

# %%
from sklearn.model_selection import train_test_split
train_sentences, test_sentences, train_labels, test_labels = train_test_split(Review, labels, test_size=0.20)

# %% [markdown]
# Preprocesamiento de las secuencias

# %%
from sklearn.model_selection import train_test_split
train_sentences, test_sentences, train_labels, test_labels = train_test_split(Review, labels, test_size=0.20)
train_sequences = tokenizer.texts_to_sequences(train_data)
train_padded = pad_sequences(train_sequences, maxlen=max_length, padding='post', truncating='post')
test_sequences = tokenizer.texts_to_sequences(test_data)
test_padded = pad_sequences(test_sequences, maxlen=max_length, padding='post', truncating='post')

# %% [markdown]
# Tokenización y generación de secuencias

# %%
#parametres
vocab_size = 10000
embedding_dim = 16
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"

# %% [markdown]
# Tokenización y acolchado de secuencias:

# %%
# Import necessary libraries
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# ... your existing code ...

# Initialize the Tokenizer class
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)

# Generate the word index dictionary for the training sentences
tokenizer.fit_on_texts(train_sentences)
word_index = tokenizer.word_index

# Generate and pad the training sequences
sequences = tokenizer.texts_to_sequences(train_sentences)

# %%
from tensorflow import keras
# Build the model
model = keras.Sequential([
    keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    keras.layers.Flatten(),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %% [markdown]
# Compilación del modelo:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
for column in df.columns:
        print(f"Column '{column}': {df[column].apply(type).unique()}")
# Out:
# Column 'review': [<class 'str'>]
# Column 'sentiment': [<class 'str'>]

# %%
# Setup the training parameters
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Build the model explicitly
model.build(input_shape=(None, max_length))  # Replace 'None' with batch size if known
# Print the model summary
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_7 (Embedding)              │ (None, 120, 16)             │         160,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_6 (Flatten)                  │ (None, 1920)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 64)                  │         122,944 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 1)                   │              65 │
# ...

# %%
# train the model
num_epochs = 5
history = model.fit(training_padded,
                    train_labels,
                    epochs=num_epochs,
                    validation_data=(testing_padded, test_labels))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-169-1b453c098049> in <cell line: 3>()
#       1 # train the model
#       2 num_epochs = 5
# ----> 3 history = model.fit(training_padded,
#       4                     train_labels,
#       5                     epochs=num_epochs,
#
# NameError: name 'training_padded' is not defined

# %%
# Assuming you are using tensorflow.keras for preprocessing
from tensorflow.keras.preprocessing.sequence import pad_sequences

# ... (Your existing code for loading/preparing data)

# Pad the training sequences
# Replace 'training_sequences' with the name of your training data containing sequences
# and 'max_length' with the maximum sequence length you defined earlier.
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding='post', truncating='post')

# train the model
num_epochs = 5
history = model.fit(training_padded,
                    train_labels,
                    epochs=num_epochs,
                    validation_data=(testing_padded, test_labels))

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Ejemplo de datos
train_data = ["Este es un texto de entrenamiento", "Otro texto para el modelo"]
train_labels = [0, 1]  # Etiquetas de entrenamiento
test_data = ["Texto de prueba para verificar el modelo", "Otro ejemplo de prueba"]
test_labels = [0, 1]  # Etiquetas de prueba

# Parámetros
vocab_size = 1000  # Ajustar según el vocabulario
max_length = 20
embedding_dim = 16
num_epochs = 5

# Tokenización y padding
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(train_data)

train_sequences = tokenizer.texts_to_sequences(train_data)
train_padded = pad_sequences(train_sequences, maxlen=max_length, padding='post', truncating='post')

test_sequences = tokenizer.texts_to_sequences(test_data)
test_padded = pad_sequences(test_sequences, maxlen=max_length, padding='post', truncating='post')

# Definición del modelo
model = Sequential([
    Embedding(vocab_size, embedding_dim, input_length=max_length),
    LSTM(64, return_sequences=True),
    LSTM(32),
    Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Entrenamiento del modelo
history = model.fit(
    train_padded,
    train_labels,
    epochs=num_epochs,
    validation_data=(test_padded, test_labels)
)

# Graficar el historial de entrenamiento
plt.plot(history.history['accuracy'], label='Precisión en Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Precisión en Validación')
plt.title('Precisión del Modelo')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend(loc='upper left')
plt.show()
